# %% [markdown]
# # LLama Index Basic Usage Example<br>
# https://www.llamaindex.ai/

# %%
pip install --quiet llama_index
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 40.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 41.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.9 MB/s eta 0:00:00

# %%
pip install --quiet llama-index-llms-openai-like

# %%
from llama_index.llms.openai_like import OpenAILike
from llama_index.core.llms import ChatMessage

# %%
application_prompt = "Write a cover letter for the following job title."
user_input = "Applied AI researcher at CIBC"

# %%
llm = OpenAILike(
    is_chat_model=True,
    temperature=0.7,
    max_tokens=100,
    model='gpt-3.5-turbo',
    api_key="sk-proj-UMyAS2Pr66RML1aalhQtT3BlbkFJ8DiOWalJnyj28C5ZaMOx"
)

# %%
message = [
    ChatMessage(role = "system", content = application_prompt),
    ChatMessage(role = "user", content = user_input)
]

# %%
print(llm.chat(message))
# Out:
# assistant: [Your Name]
# [Your Address]
# [City, State ZIP Code]
# [Your Email Address]
# [Your Phone Number]
# [Date]
#
# Hiring Manager
# CIBC
# [Company Address]
# [City, State ZIP Code]
#
# Dear Hiring Manager,
#
# I am writing to express my interest in the Applied AI Researcher position at CIBC, as advertised on your company's website. With a strong background in artificial intelligence, machine learning, and data analytics, I am confident in my ability to contribute effectively
