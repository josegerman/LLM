# %%
pip install --quiet beautifulsoup4 # web scraping

# %%
pip install --quiet langchain_community

# %%
from langchain_community .document_loaders import WebBaseLoader # bring all docs from web page

# %%
loader = WebBaseLoader("https://yorku.ca") # basic setup

# %%
documents = loader.load()

# %%
pip install --quiet langchain_openai

# %%
from langchain_openai import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings(openai_api_key = "sk-proj-UMyAS2Pr66RML1aalhQtT3BlbkFJ8DiOWalJnyj28C5ZaMOx")

# %%
pip install --quiet faiss-cpu # facebook ai similarities

# %%
pip install --quiet langchain_text_splitters

# %%
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter()
documents = text_splitter.split_documents(documents)

# %%
vectorstore = FAISS.from_documents(documents, embeddings)

# %%
retrieve = vectorstore.as_retriever()

# %%
from langchain.chains import create_retrieval_chain

# %%
template = """ Answer the following questions based on the context provided}
Question: {input}
Context: {context}
"""

# %%
from langchain.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_template(template)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-65d2587f670c> in <cell line: 1>()
# ----> 1 prompt = ChatPromptTemplate.from_template(template)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/prompts/chat.py in from_template(cls, template, **kwargs)
#     922             A new instance of this class.
#     923         """
# --> 924         prompt_template = PromptTemplate.from_template(template, **kwargs)
#     925         message = HumanMessagePromptTemplate(prompt=prompt_template)
#     926         return cls.from_messages([message])
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/prompts/prompt.py in from_template(cls, template, template_format, partial_variables, **kwargs)
#     259         """
#     260
# --> 261         input_variables = get_template_variables(template, template_format)
# ...

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(temperature=0, openai_api_key = "sk-proj-UMyAS2Pr66RML1aalhQtT3BlbkFJ8DiOWalJnyj28C5ZaMOx")

# %%
from langchain.chains.combine_documents import create_stuff_documents_chain
document_chain = create_stuff_documents_chain(llm, prompt)

# %%
chain = create_retrieval_chain(prompt, document_chain)

# %%
chain.invoke({"input":"what is going on with the disaster simulation lab"})

# %%
print(response["answer"])
