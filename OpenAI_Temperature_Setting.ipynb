# %% [markdown]
# # Experiment with OpenAI's Temperature Setting

# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key="sk-proj-UMyAS2Pr66RML1aalhQtT3BlbkFJ8DiOWalJnyj28C5ZaMOx")

response = client.chat.completions.create(
  model="gpt-3.5-turbo", temperature =1,
  messages=[
    {"role": "user", "content": "What is the top university in Canada?"}
  ]
)

# %%
response.choices[0].message.content
# Out:
# 'The top university in Canada is often considered to be the University of Toronto, which consistently ranks as one of the top universities in Canada and the world. Other top universities in Canada include McGill University, University of British Columbia, and University of Alberta.'

# %%
response.choices[0].message.content
# Out:
# 'The top university in Canada is typically considered to be the University of Toronto, which consistently ranks highly in national and international rankings. Other top universities in Canada include McGill University, University of British Columbia, and University of Alberta.'
